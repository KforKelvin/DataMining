# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

SwissRoll = np.loadtxt("swissroll.txt")
Ellipsoids = np.loadtxt("ellipsoids.txt")
Sphere = np.loadtxt("spheres.txt")
# fig = plt.figure()
# ax = plt.axes(projection='3d')
# ax.scatter3D(SwissRoll[:,0], SwissRoll[:,1], SwissRoll[:,2])
# ax.set_xlabel('Feature 1', fontsize=12, fontdict=dict(weight='bold'))
# ax.set_ylabel('Feature 2', fontsize=12, fontdict=dict(weight='bold'))
# ax.set_zlabel('Feature 3', fontsize=12,fontdict=dict(weight='bold'))
# ax.set_title('Swiss Roll', fontsize = 20)


# fig = plt.figure()
# ax = plt.axes(projection='3d')
# ax.scatter3D(Ellipsoids[:,0], Ellipsoids[:,1], Ellipsoids[:,2])
# ax.set_xlabel('Feature 1', fontsize=12, fontdict=dict(weight='bold'))
# ax.set_ylabel('Feature 2', fontsize=12, fontdict=dict(weight='bold'))
# ax.set_zlabel('Feature 3', fontsize=12,fontdict=dict(weight='bold'))

# 1.
SwissRoll_cov_matrix = np.cov(SwissRoll,rowvar=False)
print("SwissRoll_cov_matrix: \n",SwissRoll_cov_matrix)

Ellipsoids_cov_matrix = np.cov(Ellipsoids,rowvar=False)
print("Ellipsoids_cov_matrix: \n",Ellipsoids_cov_matrix)

Sphere_cov_matrix = np.cov(Sphere,rowvar=False)
print("Sphere_cov_matrix: \n",Sphere_cov_matrix)

# 2.
SwissRoll_eigenvalues, SwissRoll_eigenvectors = np.linalg.eig(SwissRoll_cov_matrix)
# print(SwissRoll_eigenvalues)
# print(SwissRoll_eigenvectors)

Ellipsoids_eigenvalues, Ellipsoids_eigenvectors = np.linalg.eig(Ellipsoids_cov_matrix)
# print(Ellipsoids_eigenvalues)
# print(Ellipsoids_eigenvectors)

Sphere_eigenvalues, Sphere_eigenvectors = np.linalg.eig(Sphere_cov_matrix)
# print(Sphere_eigenvalues)
# print(Sphere_eigenvectors)
# Out:
# SSwissRoll_cov_matrix:
#  [[43.28820984  0.15350743  4.45552413]
#  [ 0.15350743 10.5799816   0.15438407]
#  [ 4.45552413  0.15438407 47.15478185]]
# Ellipsoids_cov_matrix:
#  [[57.86612579 14.69340976  7.36636505]
#  [14.69340976  9.86297683  4.52643488]
#  [ 7.36636505  4.52643488  3.35700682]]
# Sphere_cov_matrix:
#  [[10.03680105  8.97432389  9.09405411]
#  [ 8.97432389  9.92456694  9.06781571]
#  [ 9.09405411  9.06781571 10.26264334]]

# %%
# 3. SwissRoll
pca = PCA(n_components=3)
pca_result = pca.fit_transform(SwissRoll)


pca_2d = pca_result[:, :2]
pca_1d = pca_result[:, 0]

# 2D projection
plt.scatter(pca_2d[:, 0], pca_2d[:, 1])
plt.title('2D PCA Projection')
plt.xlabel('feature 1')
plt.ylabel('feature 2')
plt.show()

# 1D projection
plt.scatter(pca_1d, np.zeros_like(pca_1d))
plt.title('1D PCA Projection')
plt.xlabel('feature 1')
plt.yticks([])
plt.show()

# %% [markdown]
# ### In this case with dataset of SwissRoll.txt, the 2D projection preserve significant information of the original database. We can still tell the dataset is swiss-roll like pattern form a 2D prespective.

# %%
# 3. Ellipsoids
pca = PCA(n_components=3)
pca_result = pca.fit_transform(Ellipsoids)


pca_2d = pca_result[:, :2]
pca_1d = pca_result[:, 0]

# 2D projection
plt.scatter(pca_2d[:, 0], pca_2d[:, 1])
plt.title('2D PCA Projection')
plt.xlabel('feature 1')
plt.ylabel('feature 2')
plt.show()

# 1D projection
plt.scatter(pca_1d, np.zeros_like(pca_1d))
plt.title('1D PCA Projection')
plt.xlabel('feature 1')
plt.yticks([])
plt.show()

# %%
# 3. Spheres
pca = PCA(n_components=3)
pca_result = pca.fit_transform(Sphere)


pca_2d = pca_result[:, :2] 
pca_1d = pca_result[:, 0]

# 2D projection
plt.scatter(pca_2d[:, 0], pca_2d[:, 1])
plt.title('2D PCA Projection')
plt.xlabel('feature 1')
plt.ylabel('feature 2')
plt.show()

# 1D projection
plt.scatter(pca_1d, np.zeros_like(pca_1d))
plt.title('1D PCA Projection')
plt.xlabel('feature 1')
plt.yticks([])
plt.show()

# %%
# I use Plotly to see things better
import numpy as np
import plotly.graph_objs as go

data = np.loadtxt('spheres.txt') 

x = data[:, 0]
y = data[:, 1]
z = data[:, 2]


fig = go.Figure(data=[go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    marker=dict(
        size=3,
        color=z,               
        colorscale='Viridis',   
        opacity=0.8
    )
)])

fig.update_layout(
    title='3D Scatter Plot of Dataset',
    scene=dict(
        xaxis_title='X Axis',
        yaxis_title='Y Axis',
        zaxis_title='Z Axis'
    )
)

# Show the figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 # I use Plotly to see things better
#       2 import numpy as np
# ----> 3 import plotly.graph_objs as go
#       5 data = np.loadtxt('spheres.txt')
#       7 x = data[:, 0]
#
# ModuleNotFoundError: No module named 'plotly'
